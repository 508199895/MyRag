# %%
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", None)
df = pd.read_parquet(r"E:\007.agent\007.project\RAG\data\squad2\plain_text\train-00000-of-00001.parquet")
# print(df.head(1))
row = df.iloc[0]
print(row)
# Out:
# id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     5733be284776f41900661182
# ...

# %%
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", None)
df = pd.read_parquet(r"E:\007.agent\007.project\RAG\data\squad2\plain_text\validation-00000-of-00001.parquet")
# print(df.head(1))
row = df.iloc[0]
print(row)
# Out:
# id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     56be4db0acb8001400a502ec
# ...
