# %%
import pandas as pd

df = pd.read_parquet("hf://datasets/BeIR/nq/corpus/corpus-00000-of-00001.parquet")
print(df.head(5))
# Out:
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。
#
# 请查看单元格中的代码，以确定故障的可能原因。
#
# 单击<a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>了解详细信息。
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。

# %%
import pandas as pd

df = pd.read_parquet("hf://datasets/BeIR/nq/queries/queries-00000-of-00001.parquet")
print(df.head(5))
# Out:
#      _id title                                               text
# 0  test0        what is non controlling interest on balance sheet
# 1  test1           how many episodes are in chicago fire season 4
# 2  test2          who sings love will keep us alive by the eagles
# 3  test3                who is the leader of the ontario pc party
# 4  test4          nitty gritty dirt band fishin in the dark album
